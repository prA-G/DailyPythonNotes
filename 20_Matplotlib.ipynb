# %% [markdown]
# # Matplotlib

# %% [markdown]
# Matplotlib is a powerful Python library used to create static, interactive, and animated visualizations.
#
# It’s like Python’s "canvas and paintbrush" — you give it your data, and it helps you paint charts, graphs, and plots.
#
# Think of it as the foundation for visualization in Python — many other libraries (like Seaborn or Pandas plotting) are actually built on top of Matplotlib.

# %% [markdown]
# # Visualisation

# %% [markdown]
# Before you crunch numbers or train models, you often need to see your data.
#
# Spot patterns (e.g., seasonal trends)
#
# Find anomalies (e.g., sudden sales drops)
#
# Communicate insights (e.g., presenting to clients or teammates)
#
# Validate assumptions (e.g., checking distribution before applying a model)

# %% [markdown]
# ## Important Libraries

# %% [markdown]
# - Matplotlib
# - Seaborne
# - Plotly
# - Bokeh

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')  # suppress all warnings

# %% [markdown]
# Line chart

# %%
# generating random numbers in numpy
x = np.random.rand(50)

# %%
x
# Out:
# array([0.92681571, 0.31587343, 0.81491981, 0.90831261, 0.80293241,
#        0.93151283, 0.83290692, 0.62594754, 0.40124186, 0.96018561,
#        0.96241296, 0.02642823, 0.61208024, 0.54505387, 0.24998551,
#        0.11876577, 0.22631571, 0.41140074, 0.09668898, 0.57768851,
#        0.38141056, 0.35469681, 0.72971468, 0.40683617, 0.12516255,
#        0.56132387, 0.91754422, 0.8357876 , 0.65635322, 0.99477095,
#        0.36026732, 0.20690842, 0.39501639, 0.51695865, 0.26949676,
#        0.64366129, 0.63541071, 0.65511358, 0.56479485, 0.02008805,
#        0.76512774, 0.33049734, 0.51347824, 0.30731973, 0.01292166,
#        0.10185344, 0.05382827, 0.74611237, 0.19573291, 0.14661772])

# %% [markdown]
# General Distribution
#
# ![image.png](attachment:image.png)

# %%
# Generating random number from normal distribution.

np.random.randn(50)
# Out:
# array([-1.57915526, -0.65324257, -0.17445451,  0.54981663,  0.4444367 ,
#        -0.12960172,  0.36727491,  0.30688896, -0.38118908, -0.86933005,
#         1.75073948,  1.14146304, -2.00937055,  2.32870511, -0.52357191,
#         0.18000796,  0.7825379 ,  1.37641693,  0.67367567,  0.36422382,
#         0.78808621, -0.13793042,  0.86228099,  0.67645824, -0.09420987,
#        -0.57178934, -1.7113721 , -1.35789949,  0.81625091, -0.52986708,
#        -0.69806386, -1.41380814,  1.41331891, -2.50704495,  0.45341403,
#         0.57900729, -0.0026535 ,  1.11288678, -0.10766559,  0.61694958,
#         1.05474729,  1.00348679,  2.0292907 ,  0.54524123,  0.03076768,
#        -0.21154278,  0.29752526,  0.58007718, -0.09363526, -0.55604477])

# %%
pd.DataFrame(np.random.randn(50), columns = ["Data"])
# Out:
#         Data
# 0  -0.202532
# 1  -0.472542
# 2   0.423474
# 3  -0.503783
# 4  -0.074658
# 5  -0.210909
# 6   2.793281
# 7   1.025926
# 8  -0.211810
# 9  -0.616722
# 10 -0.614119
# 11  0.067946
# 12 -0.602046
# 13 -0.711798
# 14  0.239644
# 15 -0.596454
# 16  1.265777
# 17 -0.103869
# 18 -2.054514
# 19 -0.927690
# 20  0.259477
# 21  0.701470
# 22 -0.402446
# 23  0.580387
# 24 -2.178301
# 25 -2.184856
# 26 -0.822981
# 27  0.547586
# 28 -0.537583
# 29  0.581662
# 30  0.879129
# 31  1.725326
# 32  0.915217
# 33  0.397996
# 34  0.819734
# 35  0.426585
# 36 -1.216446
# 37 -0.171230
# 38  0.497349
# 39  0.657191
# 40  1.613429
# 41 -0.378176
# 42  0.254657
# 43 -0.276215
# 44 -0.805321
# 45  0.377945
# 46 -0.747993
# 47  0.133632
# 48 -0.649650
# 49  1.613371

# %%
df = pd.DataFrame(np.random.randn(1000), columns = ["Data"], index = pd.date_range('2025-08-12', periods=1000))
df
# Out:
#                 Data
# 2025-08-12  2.107337
# 2025-08-13 -0.053220
# 2025-08-14  2.411077
# 2025-08-15  1.180123
# 2025-08-16  0.252759
# ...              ...
# 2028-05-03 -0.166030
# 2028-05-04 -0.494140
# 2028-05-05 -0.318479
# 2028-05-06 -1.673646
# 2028-05-07 -0.302223
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize= (20,8))  # figuresize = (x,y) >> x= len in inches,, y = breadth in inches
# Out:
# <Axes: >

# %% [markdown]
# Summary:
#
#
# Most of the values are fluctuating between -3 to 3

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# A scatter plot is a type of data visualization that displays individual data points on a two-dimensional plane (X and Y axes).
#
# Each point represents a pair of values (one from each variable).
#
# It’s perfect for visualizing the relationship or correlation between two continuous variables.

# %% [markdown]
# ## Structure
#
#
# X-axis → independent variable (input, cause)
#
# Y-axis → dependent variable (output, effect)
#
# Each point → one observation in your dataset

# %% [markdown]
# ## Uses of Scatter Plots
#
#
# 1. Find Relationships (Correlation)
#
# - Positive correlation → as X increases, Y increases
#
# - Negative correlation → as X increases, Y decreases
#
# - No correlation → random spread of points
#
# 2. Spot Outliers
#
# - Dots far from the general pattern are outliers (possible errors or special cases).
#
# 3. Cluster Detection
#
# - If points group together in specific regions → indicates clusters or categories.
#
# 4. Model Validation
#
# - Check whether data follows a linear or non-linear trend before applying regression models.
#
# 5. Compare Data Across Groups
#
# - Use color or shape to separate categories in the same plot.

# %%
x
# Out:
# array([0.92681571, 0.31587343, 0.81491981, 0.90831261, 0.80293241,
#        0.93151283, 0.83290692, 0.62594754, 0.40124186, 0.96018561,
#        0.96241296, 0.02642823, 0.61208024, 0.54505387, 0.24998551,
#        0.11876577, 0.22631571, 0.41140074, 0.09668898, 0.57768851,
#        0.38141056, 0.35469681, 0.72971468, 0.40683617, 0.12516255,
#        0.56132387, 0.91754422, 0.8357876 , 0.65635322, 0.99477095,
#        0.36026732, 0.20690842, 0.39501639, 0.51695865, 0.26949676,
#        0.64366129, 0.63541071, 0.65511358, 0.56479485, 0.02008805,
#        0.76512774, 0.33049734, 0.51347824, 0.30731973, 0.01292166,
#        0.10185344, 0.05382827, 0.74611237, 0.19573291, 0.14661772])

# %%
y = np.random.rand(50)
y
# Out:
# array([0.30182163, 0.68030392, 0.5635234 , 0.27949107, 0.04119464,
#        0.43976945, 0.77458059, 0.66169873, 0.83467856, 0.33062296,
#        0.32725583, 0.42869171, 0.0346832 , 0.71954982, 0.59666861,
#        0.63507874, 0.9082515 , 0.2758473 , 0.68004653, 0.55363342,
#        0.78496289, 0.03826917, 0.79581992, 0.9360456 , 0.28756247,
#        0.9521757 , 0.78738149, 0.33187839, 0.8695099 , 0.08402552,
#        0.3561254 , 0.80046801, 0.17119988, 0.89805341, 0.0834956 ,
#        0.28438281, 0.16208347, 0.53815892, 0.50473318, 0.33548684,
#        0.95254595, 0.8467304 , 0.46156731, 0.92132619, 0.84034719,
#        0.18731469, 0.47265339, 0.38418998, 0.86240178, 0.75886264])

# %%
plt.scatter(x, y)

# %% [markdown]
# ## Changing the color

# %%
plt.scatter(x, y, c = 'r')

# %% [markdown]
# ## Adding marker

# %%
plt.scatter(x, y, c = 'r', marker='*')

# %%
plt.scatter(x, y, c = 'r', marker='X')

# %%
plt.scatter(x, y, c = 'r', marker='+')

# %% [markdown]
# # Line Plot

# %% [markdown]
# A line plot is a type of chart that uses straight lines to connect individual data points.
#
# It’s great for showing how a variable changes over time or across an ordered sequence.
#
# In Matplotlib, it’s usually created with plt.plot().

# %% [markdown]
# ## Uses of Line Plot
#
#
# - Trend Analysis → See whether something is increasing, decreasing, or staying constant over time.
#
# - Time Series Data → Stock prices, temperature changes, sales over months.
#
# - Comparing Multiple Series → Plotting multiple lines to compare different datasets.
#
# - Detecting Patterns → Seasonality, cycles, and sudden spikes or drops.

# %%
x = [1, 2, 3, 4, 5]  # Days
y = [5, 2, 7, 8, 1] # price of stock

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y
# Out:
# [5, 2, 7, 8, 1]

# %%
plt.plot(x, y)

# %% [markdown]
# ## Detailing in the plot

# %% [markdown]
# ### Adding the Title

# %%
plt.plot(x, y)
plt.title("Title : Line Chart")
# Out:
# Text(0.5, 1.0, 'Title : Line Chart')

# %% [markdown]
# ### Labelling x and y axis

# %%
plt.plot(x, y)
plt.title("Title : Line Chart")
plt.xlabel("Days on x axis")
plt.ylabel("Stock Price on y axis")
# Out:
# Text(0, 0.5, 'Stock Price on y axis')

# %% [markdown]
# ### Removing text detail

# %%
plt.plot(x, y)
plt.title("Title : Line Chart")
plt.xlabel("Days on x axis")
plt.ylabel("Stock Price on y axis")
plt.show()  # formal way to show the canvas

# %% [markdown]
# ### Changing the color of line

# %%
plt.plot(x, y, color = "red")
plt.title("Title : Line Chart")
plt.xlabel("Days on x axis")
plt.ylabel("Stock Price on y axis")
plt.show()  # formal way to show the canvas

# %% [markdown]
# ### PLotting the point of x and y

# %%
plt.plot(x, y, color = "red", marker = "o")
plt.title("Title : Line Chart")
plt.xlabel("Days on x axis")
plt.ylabel("Stock Price on y axis")
plt.show()

# %% [markdown]
# ### Changing the Nature of the Line

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = "--")
plt.title("Title : Line Chart")
plt.xlabel("Days on x axis")
plt.ylabel("Stock Price on y axis")
plt.show()

# %% [markdown]
# ### Increasing the line width

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = "--", linewidth = 4)
plt.title("Title : Line Chart")
plt.xlabel("Days on x axis")
plt.ylabel("Stock Price on y axis")
plt.show()

# %% [markdown]
# ### Increasing the plot size

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = "--", linewidth = 4, markersize = 15)
plt.title("Title : Line Chart")
plt.xlabel("Days on x axis")
plt.ylabel("Stock Price on y axis")
plt.show()

# %% [markdown]
# ### Adding grid

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = "--", linewidth = 4, markersize = 14)
plt.title("Title : Line Chart")
plt.xlabel("Days on x axis")
plt.ylabel("Stock Price on y axis")
plt.grid()

# %% [markdown]
# ## Line plot with two variable points

# %%
x = [1,2,3,4,5]
y1 = [5,1,7,8,2]
y2 = [7,8,3,5,1]

# %%
plt.plot(x, y1, color = "yellow", marker = "o", linestyle= "--", linewidth = 3, markersize = 6, label = "line y1")

# %%
plt.plot(x, y1, color = "yellow", marker = "o", linestyle= "--", linewidth = 3, markersize = 6, label = "line y1")
plt.plot(x, y2, color = "red", marker = "o", linestyle= "--", linewidth = 3, markersize = 6, label = "line y2")

# %%
plt.plot(x, y1, color = "yellow", marker = "o", linestyle= "--", linewidth = 3, markersize = 6, label = "y1 as Tata")
plt.plot(x, y2, color = "red", marker = "o", linestyle= "--", linewidth = 3, markersize = 6, label = "y2 as Reliance")

plt.title("Multiple lines in one plot")
plt.xlabel("Days")
plt.ylabel("Stock price")
plt.legend()
plt.show()

# %%
x  = np.linspace(0, 10, 100)

# %% [markdown]
# ### Mathematical plot

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x), '--')
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x), '.-')
plt.plot(x, np.cos(x), ':')

# %% [markdown]
# ### Two seperate plot on same plot

# %%
plt.figure()  # initializing a page to make plot
plt.subplot(1,2,1)  # 1 rows, 2 columns, 1st row
plt.plot(x, np.sin(x))

plt.subplot(1,2,2)
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure()  
plt.subplot(2, 1, 1)  # 2 rows, 1 column, take 1st row
plt.plot(x, np.sin(x), color = "red")

plt.subplot(2, 1,2)
plt.plot(x, np.cos(x))

plt.show()

# %%
x = [1, 2, 5, 9, 3, 7, 4, 1]
y = [2, 5, 6, 3, 1, 4, 9, 2]

# %%
plt.figure()  
plt.subplot(2, 2, 1) 
plt.plot(x, np.sin(x), color = "red", linestyle = ":", label = "sin(x)")
plt.legend()


plt.subplot(2, 2,2)
plt.plot(x, np.cos(x), color = "green", linestyle= "--", label = "cos(x)")
plt.legend()


plt.subplot(2,2,3)
plt.plot(y, np.tan(y), color = "blue", linestyle = "-", label = "tan(y)")
plt.legend()


plt.subplot(2, 2, 4)
plt.plot(y, np.cos(y), color = "black", linestyle = ":", label = "cos(y)")
plt.legend()


plt.show()

# %%
x  = np.linspace(0, 10, 100)

# %%
plt.plot(x, np.sin(x), color = "green")

# %% [markdown]
# ### Changing range value of x and y

# %%
plt.plot(x, np.sin(x-0), color = "green")
plt.ylim(-1.5, 1.5)
plt.xlim(1,15)
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = "green")
plt.ylim(-1.5, 1.5)
plt.xlim(1,15)
plt.title("Example")
plt.xlabel("x-label")
plt.ylabel("y-label")
plt.grid()
plt.axis('equal')
plt.show()

# %% [markdown]
# # Histogram

# %% [markdown]
# A histogram is a type of graph that groups data into ranges (bins) and shows how many data points fall into each range.
#
# Instead of showing exact values (like a bar chart), it shows the distribution of data.
#
# In Python (Matplotlib), you create it with plt.hist().

# %% [markdown]
# ## Uses of Histogram
#
#
# - Understand Data Distribution → Check if data is normal, skewed, uniform, etc.
#
# - Detect Outliers → See unusual high/low values.
#
# - Feature Engineering → Decide data transformations (log scale, normalization, etc.).
#
# - Statistical Analysis → Before applying ML models, check if assumptions about distribution hold.
#
# - Quality Control → Manufacturing defects, exam score analysis, etc.

# %% [markdown]
# Divide the data into range of 10 (10 bins)

# %%
data = np.random.randn(1000)  # by default 10 bins are created
plt.hist(data)
plt.show()

# %%
data = np.random.randn(1000)  
plt.hist(data, color= "red", bins= 20)
plt.show()

# %% [markdown]
# ## Stacked histogram

# %% [markdown]
# Two histogram together

# %%
data1 = np.random.normal(0, 1, 5000)
data2 = np.random.normal(3, 2, 5000)

# %%
plt.hist([data1, data2], bins = 20, color= ['r', 'b'], label = ['Distribution 1', 'Distribution 2'])
plt.xlabel("values")
plt.ylabel("Frequency")
plt.title("Stacked Histogram")
plt.show()

# %% [markdown]
# # Bar Plot

# %% [markdown]
# A bar plot (or bar chart) uses rectangular bars to represent and compare categorical data.
#
# Length/height of each bar → the value it represents.
#
# Bars can be vertical or horizontal.
#
# In Python’s Matplotlib, created using plt.bar() (vertical) or plt.barh() (horizontal).

# %% [markdown]
# ## Uses in Data Science
#
#
# - Category Comparison → Compare values across categories (e.g., sales by product, population by city).
#
# - Ranking → Show which categories lead or lag.
#
# - Frequency Counts → How many times each category appears.
#
# - Grouped/Stacked Analysis → Compare multiple variables across categories.
#
# - Business Insights → Market share, survey results, budget allocation, etc.

# %%
x = ["a", "b", "c", "d"]  # name of employee
y = [4, 6, 1, 10] # no of projects

# %%
plt.bar(x, y) # be default verticle plot
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### Changing the color

# %%
plt.bar(x, y, color ='red')
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## Change into horizontal

# %%
plt.barh(x, y, color = "green")
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Pie Chart

# %% [markdown]
# A pie chart is a circular chart divided into slices to represent the proportion or percentage of different categories in a dataset.
#
# Each slice’s angle/area corresponds to its share of the total.
#
# In Python’s Matplotlib, created with plt.pie().

# %% [markdown]
# ## Uses of Pie chart
#
#
# - Proportion Analysis → Show percentage contribution of each category to the whole.
#
# - Market Share → Compare competitors’ shares in a market.
#
# - Budget Allocation → Show distribution of expenses.
#
# - Survey Results → Visualize response proportions.
#
# - Quick Overviews → Great for high-level presentations (but not for precise comparisons).

# %%
langs = ["C", "Python", "Java", "R", "Matlab"]
students = [20, 88, 72, 10, 8]

# %%
plt.pie(students, labels= langs)
plt.title("Popularity of Programming languages")
plt.show()

# %% [markdown]
# ## Adding percentage for each section

# %%
plt.pie(students, labels= langs, autopct="%1.1f%%")
plt.title("Popularity of Programming languages")
plt.show()

# %% [markdown]
# ## Focusing on only one segment

# %%
explode = (0.0, 0.2, 0.2, 0.2, 0.2)
plt.pie(students, labels= langs, autopct="%1.1f%%", explode= explode)
plt.title("Popularity of Programming languages")
plt.show()

# %% [markdown]
# ## Adding Shadow

# %%
explode = (0.0, 0.2, 0.2, 0.2, 0.2)
plt.pie(students, labels= langs, autopct="%1.1f%%", explode= explode, shadow= True)
plt.title("Popularity of Programming languages")
plt.show()

# %% [markdown]
# # 3-D Plot in matplotlib

# %%
x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection= '3d')
ax.scatter(x, y, z, c="red")

# %% [markdown]
# # Implementing Data Toolkit on CSV file

# %%
data = pd.read_csv("Bank_churn.csv")  # Data of customer exited from bank

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# Making relation between Age and Balance

# %%
plt.scatter(x = data['Age'], y = data['Balance'])

# %%
data.plot.scatter(x = 'Age', y = 'Balance')
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %% [markdown]
# Histogram of Age

# %%
plt.hist(data['Age'], color = 'green')
# Out:
# (array([ 611., 2179., 3629., 1871.,  828.,  523.,  208.,  127.,   20.,
#            4.]),
#  array([18. , 25.4, 32.8, 40.2, 47.6, 55. , 62.4, 69.8, 77.2, 84.6, 92. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Histogram of balance column

# %%
plt.hist(data['Balance'], color = 'green')
# Out:
# (array([3.623e+03, 6.900e+01, 3.600e+02, 1.173e+03, 2.081e+03, 1.747e+03,
#         7.290e+02, 1.860e+02, 3.000e+01, 2.000e+00]),
#  array([     0.   ,  25089.809,  50179.618,  75269.427, 100359.236,
#         125449.045, 150538.854, 175628.663, 200718.472, 225808.281,
#         250898.09 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Outliers

# %% [markdown]
# An outlier is a data point that is way too different from the rest.

# %% [markdown]
# 1,2,3,4,5,100 >> 100 is outliers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Boxplot
#
# used to detect outliers

# %%
data.boxplot(column = 'Balance')
# Out:
# <Axes: >

# %%
plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x28177bd3dd0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x28177c36410>,
#  'cmins': <matplotlib.collections.LineCollection at 0x28177b9dd50>,
#  'cbars': <matplotlib.collections.LineCollection at 0x28177c593d0>}

# %% [markdown]
# ## Area Plot

# %% [markdown]
# **Variables changed over time**

# %% [markdown]
# An area plot is like a line plot, but the space under the line is filled with color.
#
# It shows how values change over time and also highlights the magnitude of those values.
#
# In Matplotlib, you create it with plt.fill_between() or Pandas’ .plot(kind='area').

# %% [markdown]
# ### Uses
#
#
# - Show Cumulative Trends → Track how a quantity builds up over time.
#
# - Compare Multiple Series → Stacked area plots can show how each category contributes to the total.
#
# - Highlight Volume → Better visual impact than a simple line plot.
#
# - Time Series Analysis → Revenue growth, population increase, stock performance.

# %%
years = [ 2021, 2018, 2022, 2023, 2027]
category1 = [20,25,29, 24, 35]
category2 = [10,15,19, 14, 25]
category3 = [5, 8, 12, 9, 12]

# %%
plt.stackplot(years, category1, category2, category3, labels=["category1", "category2", "category3"] , 
              colors=["skyblue", "orange", "pink"] )
plt.xlabel("years")
plt.ylabel("Values")
plt.title("Area Plot")
plt.legend()
plt.show()
