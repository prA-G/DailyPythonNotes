# %% [markdown]
# # Introduction on Seaborn

# %% [markdown]
# **Statistical Data Visualization**

# %% [markdown]
# Seaborn is a Python data visualization library built on top of Matplotlib.
#
# It comes with prettier default styles and is optimized for statistical plots.
#
# Makes it easier to create informative, attractive, and complex plots with less code.

# %% [markdown]
# ## Uses

# %% [markdown]
# - Cleaner, modern designs without manually styling.
#
# - Built-in statistical functions (like regression lines, distribution plots).
#
# - Works directly with Pandas DataFrames (no need to manually extract lists).
#
# - Supports themes, color palettes, and automatic legends.
#
# - Offers specialized plots that Matplotlib doesn’t have natively.

# %%
# %pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data sets of seaborn

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('planets')
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.shape
# Out:
# (244, 7)

# %%
sns.load_dataset('exercise')
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# # Numerical Data Plotting

# %% [markdown]
# `relplot` has option of plotting both categorical and numerical data
# - Relation between two variable
# - relationship plot

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# How tip is varying wrt total bill?

# %%
sns.relplot(x= 'total_bill', y= 'tip', data= df)

# %% [markdown]
# *Insights* : As the bill increases, Tips also increases >> @ $50 tip is $10

# %% [markdown]
# Relationship between two variable,  By default it is scatter plot, kind = line if want to change the line

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# To distinguish between smoker and non smoker

# %%
sns.relplot(x= 'total_bill', y= 'tip', data= df, hue= 'smoker')

# %% [markdown]
# *Insights* :
# - Number of smokers are comparatively more in comaprison to non smoker
# - Non smoker give more tips in comaprison to smoker
# - Customer who smoke gave highest tip

# %% [markdown]
# To distinguish the day

# %%
sns.relplot(x= 'total_bill', y= 'tip', data= df, hue= 'day')

# %% [markdown]
# *Insights* : The day people visited most is Saturday

# %% [markdown]
# To distinguish between male and female

# %%
sns.relplot(x= 'total_bill', y= 'tip', data= df, hue= 'sex')

# %% [markdown]
# To know number of persons

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x= 'total_bill', y= 'tip', data= df, hue= 'size')

# %% [markdown]
# - Different color coding for column value that we pass
# - different shade will make problem to distinguish

# %% [markdown]
# `style()` give different representation of column value instead of color

# %%
sns.relplot(x= 'total_bill', y= 'tip', data= df, style= 'size')

# %%
sns.relplot(x= 'total_bill', y= 'tip', data= df, style= 'smoker', hue='time')

# %%
sns.relplot(x= 'total_bill', y= 'tip', data= df, style= 'day', hue='sex')

# %%
sns.relplot(x= 'total_bill', y= 'tip', data= df, style= 'sex', hue='day')

# %%
sns.relplot(x= 'total_bill', y= 'tip', data= df, style= 'smoker', hue='sex')

# %% [markdown]
# ## Line plot

# %% [markdown]
# relplot to make a line plot >> generating a data
#
# To understanding the trending data
#
# A time column/ sequences generally involved

# %%
time = np.arange(500)
value = np.random.randn(500).cumsum()

# %%
df = pd.DataFrame({'time': time, 'value': value})
df
# Out:
#      time      value
# 0       0  -1.161727
# 1       1  -0.702963
# 2       2  -1.984522
# 3       3  -1.324298
# 4       4   0.296281
# ..    ...        ...
# 495   495 -19.848689
# 496   496 -21.158032
# 497   497 -18.867935
# 498   498 -17.736479
# 499   499 -17.243285
#
# [500 rows x 2 columns]

# %%
sns.relplot(x = 'time', y = 'value', kind = 'line', data = df, sort= True)

# %%
fmri = sns.load_dataset('fmri')

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x = 'timepoint', y= 'signal', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y= 'signal', kind = 'line', data = fmri, ci = 'sd')

# %% [markdown]
# ci = confidence interval, data point will between only its shaded region

# %% [markdown]
# - To remove that shaded region

# %%
sns.relplot(x = 'timepoint', y= 'signal', estimator = None, kind = 'line', data = fmri, ci = 'sd')

# %%
sns.relplot(x = 'timepoint', y= 'signal', kind = 'line', data = fmri)

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %% [markdown]
# Make event as Hue

# %%
sns.relplot(x = 'timepoint', y= 'signal', kind = 'line', data = fmri, hue= 'event')

# %%
sns.relplot(x = 'timepoint', y= 'signal', kind = 'line', data = fmri, hue= 'region')

# %%
sns.relplot(x = 'timepoint', y= 'signal', kind = 'line', data = fmri, hue= 'event', style = 'region')

# %%
sns.relplot(x = 'timepoint', y= 'signal', kind = 'line', data = fmri, hue= 'event', style = 'region', dashes= False)

# %%
sns.relplot(x = 'timepoint', y= 'signal', kind = 'line', data = fmri, hue= 'event', style = 'region', dashes= False, markers= True)

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Seperating one plot to two plot

# %% [markdown]
# Two subplot based on a column

# %%
sns.relplot(x = 'total_bill', y= 'tip', hue= 'smoker', data = tips)

# %%
sns.relplot(x = 'total_bill', y= 'tip', hue= 'smoker', data = tips, col= 'time')

# %%
sns.relplot(x = 'total_bill', y= 'tip', hue= 'smoker', data = tips, col= 'day')

# %%
sns.relplot(x = 'total_bill', y= 'tip', hue= 'smoker', data = tips, col= 'sex')

# %%
sns.relplot(x = 'total_bill', y= 'tip', hue= 'day', data = tips, col= 'smoker')

# %%
sns.relplot(x = 'total_bill', y= 'tip', hue= 'smoker', data = tips, col= 'size')

# %% [markdown]
# # Categorical Data Plot

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# Plot between day and total bill, day is categorical column

# %%
sns.catplot(x= 'day', y= 'total_bill', data= tips)

# %% [markdown]
# *Insights*:
# - Many people arrives on weekend i.e. saturday and sunday

# %% [markdown]
# Due to density, data points are overlapping, which can not showing clear data

# %% [markdown]
# To avoid this we use, swarm plot

# %%
sns.catplot(x= 'day', y= 'total_bill', data= tips, kind= 'swarm')

# %%
sns.catplot(x = 'day', y='total_bill', data= tips, kind= 'box')

# %%
sns.catplot(x = 'day', y='total_bill', data= tips, kind= 'violin')

# %%
sns.catplot(x = 'day', y='total_bill', data= tips, kind= 'boxen')

# %%
sns.barplot(x= 'day', y= 'total_bill', data= tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Draw a plot of two variable with distributions
sns.jointplot(x= tips.total_bill, y= tips.tip)

# %% [markdown]
# Join plots to understand relationship and also distribution of two variable

# %%
sns.jointplot(x= tips.total_bill, y= tips.tip, kind= 'reg')

# %% [markdown]
# `reg` : regression line to show relationship

# %% [markdown]
# `Kernel density estimator` : Density of data

# %%
sns.jointplot(x= tips.total_bill, y= tips.tip, kind= 'hex')

# %% [markdown]
# Kernel Density Estimator
# - Useful in Meterological Department

# %%
sns.jointplot(x= tips.total_bill, y= tips.tip, kind= 'kde')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips)  # makes scatter plot with respect to all numerical columns

# %%
sns.pairplot(tips, hue= 'smoker')

# %%
sns.pairplot(tips, hue= 'sex')

# %%
sns.pairplot(tips, hue= 'smoker', palette='coolwarm')

# %%
sns.pairplot(tips, hue= 'smoker', palette='husl')

# %%
sns.boxplot(x= 'day', y= 'total_bill', data= tips, palette= 'rainbow' )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x= 'day', y= 'total_bill', data= tips, palette= 'rainbow' , orient= 'h')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data= tips, palette= 'husl' , orient= 'h')
# Out:
# <Axes: >

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1 = tips[['total_bill', 'tip', 'size']]

# %%
df1
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %% [markdown]
# # Co-relation

# %% [markdown]
# How two features x and y varies.
#
#
# If x/y are increasing/ decreasing or not

# %%
df1.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# - If total bill increasing >> Tip will be increased by 67% and size is increased by 59%
# - If tip is increasing >> total bill will be increased by 67% and size will be increased by 48%
# - If size is increasing >> total bill will be increased by 59% and tip will be increased by 48%

# %% [markdown]
# # Heatmap

# %% [markdown]
# Value encoded with different colors

# %%
sns.heatmap(df1.corr(), cmap= 'coolwarm')
# Out:
# <Axes: >

# %%
sns.heatmap(df1.corr(), cmap= 'coolwarm', annot= True)
# Out:
# <Axes: >

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x = 'sex', data= tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x='total_bill', y= 'tip', data= tips)

# %%
sns.lmplot(x='total_bill', y= 'tip', data= tips, height= 15)

# %%
sns.lmplot(x='total_bill', y= 'tip', data= tips, height=15, aspect= 1)

# %%
sns.lmplot(x='total_bill', y= 'tip', data= tips, height=15, aspect= 2)

# %%
sns.lmplot(x='total_bill', y= 'tip', data= tips, height=15, aspect= 3)
