# %%
# %pip install pandas

# %% [markdown]
# # Some Advance Functions On Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()  # 1st five rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()  # last five rows
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 886          887         0       2                    Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss Margaret Edith
# 888          889         0       3  Johnston, Miss Catherine Helen "Carrie"
# 889          890         1       1                    Behr, Mr. Karl Howell
# 890          891         0       3                      Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## Statistical Information of Column

# %% [markdown]
# To get statistical information about numerical column of data frame , we use :
#
# `dataframe.describe()`

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Data are of two types:
# 1. Qualitative ----> Categorical ----> String
# 2. Quantitative -----> Numerical
#
# - Numerical are of two types:
# - Countinuous : Float --> Any value on number line
# - Discrete : Integer --> Only whole number, finite value.

# %% [markdown]
# - `count` : For each numerical column we have number of elements.
# - `mean` : Avg of column
# - `std` : standard deviation of the col
# - `min` : Minimum value of any column
# - `25%` : 25% percentile : Above than 25% of people
# - `50%` : 50% percentile : Above than 50% of people
# - `75%` : 75% percentile : Above than 75% of people
# - `max` : Maximum value of column.

# %% [markdown]
# #### Five points summary:
# - min
# - 25%
# - 50%
# - 75%
# - max
#
# These five points give a lots of information about data.

# %% [markdown]
# Subset of DataFrame:

# %%
df[["PassengerId", "Survived", "Pclass"]]
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [891 rows x 3 columns]

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes == "objects"  # objects are string data types
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %% [markdown]
# Return those value where condition is True

# %%
df.dtypes[df.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %% [markdown]
# ### To get the index

# %%
df.dtypes[df.dtypes == "object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# ### Accessing any str data from col

# %%
df[df.dtypes[df.dtypes == "object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                        Graham, Miss Margaret Edith  female
# 888            Johnston, Miss Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %% [markdown]
# ### Accessing any numerical data from the col

# %%
df[df.dtypes[df.dtypes != "object"].index]
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
df[df.dtypes[df.dtypes != "object"].index].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### To get info about categorical data

# %%
df.describe(include= "object") # only str col
# Out:
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
df.describe(include= "all")  # for both numerical and str col
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# In order to know numerical colum information in terms of categorical col info

# %%
df.astype('object').describe()
# Out:
#         PassengerId  Survived  Pclass                     Name   Sex    Age  \
# count           891       891     891                      891   891  714.0
# unique          891         2       3                      891     2   88.0
# top               1         0       3  Braund, Mr. Owen Harris  male   24.0
# freq              1       549     491                        1   577   30.0
#
#         SibSp  Parch  Ticket    Fare Cabin Embarked
# count     891    891     891  891.00   204      889
# unique      7      7     681  248.00   147        3
# top         0      0  347082    8.05    G6        S
# freq      608    678       7   43.00     4      644

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ### Accessing first nth row

# %%
df[0:100]  # 0: start index  100: end index
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %% [markdown]
# ### Accessing from 0 to 100 element evry 5th element

# %%
df[0:100:5]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 5             6         0       3
# 10           11         1       3
# 15           16         1       2
# 20           21         0       2
# 25           26         1       3
# 30           31         0       1
# 35           36         0       1
# 40           41         0       3
# 45           46         0       3
# 50           51         0       3
# 55           56         1       1
# 60           61         0       3
# 65           66         1       3
# 70           71         0       2
# 75           76         0       3
# 80           81         0       3
# 85           86         1       3
# 90           91         0       3
# 95           96         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 5                                    Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# ### Creating a new column

# %%
df["New_col"] = "PW"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### Creating new column from existing column.

# %% [markdown]
# - feature engineerirng ---> Calculation on some existing col and creating a new one.

# %%
df["SibSp"]
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    1
# 889    0
# 890    0
# Name: SibSp, Length: 891, dtype: int64

# %%
df["Parch"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 886    0
# 887    0
# 888    2
# 889    0
# 890    0
# Name: Parch, Length: 891, dtype: int64

# %%
df["Family"] = df["SibSp"] + df["Parch"]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### To know different category of any particular class/col

# %%
pd.Categorical(df["Pclass"])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(df["Cabin"])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %% [markdown]
# ### To check unique value of col

# %%
df["Cabin"].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# ### To count the unique value

# %%
df["Sex"].nunique()
# Out:
# 2

# %%
df["Pclass"].nunique()
# Out:
# 3

# %%
df["Cabin"].nunique()
# Out:
# 147

# %%
df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# In order to know how many male and female are there seperately

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["Cabin"].value_counts()
# Out:
# Cabin
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F2             3
# D              3
#               ..
# E17            1
# A24            1
# C50            1
# B42            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %% [markdown]
# ### To get % of each elements of any particular col

# %%
df["Sex"].value_counts(normalize=True)
# Out:
# Sex
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64

# %%
df["Sex"].value_counts(normalize=True)*100
# Out:
# Sex
# male      64.758698
# female    35.241302
# Name: proportion, dtype: float64

# %% [markdown]
# ## Real Life Based Questions on Data Set

# %% [markdown]
# 1. How many passengers are less than 5 years old?

# %%
df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"]<5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df["Age"]< 5]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3            Palsson, Master Gosta Leonard
# 10            11         1       3           Sandstrom, Miss Marguerite Rut
# 16            17         0       3                      Rice, Master Eugene
# 43            44         1       2  Laroche, Miss Simonne Marie Anne Andree
# 63            64         0       3                     Skoog, Master Harald
# 78            79         1       2             Caldwell, Master Alden Gates
# 119          120         0       3         Andersson, Miss Ellis Anna Maria
# 164          165         0       3              Panula, Master Eino Viljami
# 171          172         0       3                      Rice, Master Arthur
# 172          173         1       3              Johnson, Miss Eleanor Ileen
# 183          184         1       2                 Becker, Master Richard F
# ...

# %%
df[df["Age"]< 5].shape  # 40 people are there
# Out:
# (40, 14)

# %%
len(df[df["Age"]< 5])
# Out:
# 40

# %% [markdown]
# 2. Name of the childred who are less than five years old.

# %%
df[df["Age"] < 5]["Name"]
# Out:
# 7                Palsson, Master Gosta Leonard
# 10              Sandstrom, Miss Marguerite Rut
# 16                         Rice, Master Eugene
# 43     Laroche, Miss Simonne Marie Anne Andree
# 63                        Skoog, Master Harald
# 78                Caldwell, Master Alden Gates
# 119           Andersson, Miss Ellis Anna Maria
# 164                Panula, Master Eino Viljami
# 171                        Rice, Master Arthur
# 172                Johnson, Miss Eleanor Ileen
# 183                   Becker, Master Richard F
# 184         Kink-Heilmann, Miss Luise Gretchen
# 193                  Navratil, Master Michel M
# 205                  Strom, Miss Telma Matilda
# 261           Asplund, Master Edvin Rojj Felix
# 297                Allison, Miss Helen Loraine
# 305              Allison, Master Hudson Trevor
# 340              Navratil, Master Edmond Roger
# 348      Coutts, Master William Loch "William"
# 374                  Palsson, Miss Stina Viola
# ...

# %%
list(df[df["Age"] < 5]["Name"])
# Out:
# ['Palsson, Master Gosta Leonard',
#  'Sandstrom, Miss Marguerite Rut',
#  'Rice, Master Eugene',
#  'Laroche, Miss Simonne Marie Anne Andree',
#  'Skoog, Master Harald',
#  'Caldwell, Master Alden Gates',
#  'Andersson, Miss Ellis Anna Maria',
#  'Panula, Master Eino Viljami',
#  'Rice, Master Arthur',
#  'Johnson, Miss Eleanor Ileen',
#  'Becker, Master Richard F',
#  'Kink-Heilmann, Miss Luise Gretchen',
#  'Navratil, Master Michel M',
#  'Strom, Miss Telma Matilda',
#  'Asplund, Master Edvin Rojj Felix',
#  'Allison, Miss Helen Loraine',
#  'Allison, Master Hudson Trevor',
#  'Navratil, Master Edmond Roger',
#  'Coutts, Master William Loch "William"',
#  'Palsson, Miss Stina Viola',
#  'Nakid, Miss Maria ("Mary")',
#  'Goodwin, Master Sidney Leonard',
#  'Richards, Master William Rowe',
#  'Dodge, Master Washington',
#  'Baclini, Miss Helene Barbara',
#  'Hirvonen, Miss Hildur E',
#  'Quick, Miss Phyllis May',
#  'Becker, Miss Marion Louise',
#  'Skoog, Miss Margit Elizabeth',
# ...

# %% [markdown]
# 3. How many persons are less than 18 years old?

# %%
len(df[df["Age"] < 18])
# Out:
# 113

# %% [markdown]
# 4. How many persons are greater than 18 years old?

# %%
len(df[df["Age"] > 18])
# Out:
# 575

# %% [markdown]
# 5. How many passengers paid less than average fair?

# %%
df["Fare"].mean()
# Out:
# np.float64(32.204207968574636)

# %%
len(df[df["Fare"]< 32])
# Out:
# 680

# %%
len(df[df["Fare"] < df["Fare"].mean()])
# Out:
# 680

# %% [markdown]
# 6. How many passengers have paid 0 fare?

# %%
len(df[df["Fare"] == 0])
# Out:
# 15

# %% [markdown]
# 7. How many passengers are Male?

# %%
len(df[df["Sex"] == "male"])
# Out:
# 577

# %% [markdown]
# 8. How many passengers are female?

# %%
len(df[df["Sex"] == "female"])
# Out:
# 314

# %%
len(df[df["Sex"] != "male"])
# Out:
# 314

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# 9. How many passengers are of Class 1?

# %%
len(df[df["Pclass"] == 1])
# Out:
# 216

# %% [markdown]
# 10. How many passengers survived?

# %%
len(df[df["Survived"] == True])
# Out:
# 342

# %% [markdown]
# 11. How many females paid more than avg fare?

# %%
len(df[(df["Sex"] == "female") &  (df["Fare"] > df["Fare"].mean())])
# Out:
# 104

# %% [markdown]
# 11. How many males paid less than avg fare?

# %%
len(df[(df["Sex"] == "male") & (df["Fare"] < df["Fare"].mean())])
# Out:
# 470

# %% [markdown]
# 12. Peoples have paid maximum fare?

# %%
df[df["Fare"] == df["Fare"].max()]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                     Ward, Miss Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#     New_col  Family
# 258      PW       0
# 679      PW       1
# 737      PW       0

# %% [markdown]
# - Number of people

# %%
len(df[df["Fare"] == df["Fare"].max()])
# Out:
# 3

# %%
df[df["Fare"] == df["Fare"].max()].Name
# Out:
# 258                       Ward, Miss Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %% [markdown]
# - Name of people

# %% [markdown]
# #### By using NumPy

# %%
import numpy as np

# %%
np.mean(df["Fare"])
# Out:
# np.float64(32.204207968574636)

# %%
df["Fare"].mean()
# Out:
# np.float64(32.204207968574636)

# %%
df.Fare.mean()
# Out:
# np.float64(32.204207968574636)

# %%
max(df.Fare)
# Out:
# 512.3292

# %%
min(df.Fare)
# Out:
# 0.0
