# %% [markdown]
# # Advanced Functions in Pandas

# %%
# %pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv")

# %%
pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv", header= None)
# Out:
#               0         1       2   \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
#                                                     3       4    5      6   \
# 0                                                 Name     Sex  Age  SibSp
# 1                              Braund, Mr. Owen Harris    male   22      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                                Heikkinen, Miss Laina  female   26      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# ..                                                 ...     ...  ...    ...
# ...

# %% [markdown]
# # Accessing Row and Column of DataFrame

# %% [markdown]
# ## Accessing 1st nth row
#
# `dataframe[x:y:z]`
#
# - x : Start , y : End, z = Steps
# - Just like string slicing

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[0:100]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
df[0:100:5]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 5             6         0       3
# 10           11         1       3
# 15           16         1       2
# 20           21         0       2
# 25           26         1       3
# 30           31         0       1
# 35           36         0       1
# 40           41         0       3
# 45           46         0       3
# 50           51         0       3
# 55           56         1       1
# 60           61         0       3
# 65           66         1       3
# 70           71         0       2
# 75           76         0       3
# 80           81         0       3
# 85           86         1       3
# 90           91         0       3
# 95           96         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 5                                    Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# ## Implicit / Integer / Internal Indexing

# %% [markdown]
# iloc = implicit , integer or internal indexing
#
# - Always require python internal indexing
# - whatever indexing Pandas give by-default , we can use it with

# %%
df[0:3]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.iloc[0:3]  # start from 0 and go till 2 (3-1)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# ## Explicit / Name Indexing

# %% [markdown]
# These indexing in which end point is also included.

# %%
df.loc[0:3]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df.loc[0:2, ["Name", "Sex"]]  # if we use iloc in place of loc, we will get error as iloc in number indexing
# Out:
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                              Heikkinen, Miss Laina  female

# %% [markdown]
# If we want to use iloc only, we have to use indexing in place of name.
# - like in place of col name "Sex" we will use index no. 4

# %%
df.iloc[0:3, 3:5]
# Out:
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                              Heikkinen, Miss Laina  female

# %%
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                  Heikkinen, Miss Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                          Graham, Miss Margaret Edith
# 888              Johnston, Miss Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
list(df["Name"][2:5])
# Out:
# ['Heikkinen, Miss Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry']

# %% [markdown]
# Converting List to series

# %%
pd.Series(list(df["Name"][2:5]))
# Out:
# 0                           Heikkinen, Miss Laina
# 1    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 2                        Allen, Mr. William Henry
# dtype: object

# %%
s = pd.Series(list(df["Name"][2:5]), index = ["a", "b", "c"])
s
# Out:
# a                           Heikkinen, Miss Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s1 = pd.Series(list(df["Name"][5:8]))
s1
# Out:
# 0                 Moran, Mr. James
# 1          McCarthy, Mr. Timothy J
# 2    Palsson, Master Gosta Leonard
# dtype: object

# %% [markdown]
# ### Concatenate two string

# %% [markdown]
# Series with different indices and data frame cannot be concatenated by using '+' symbol
#
#
# series s has index [a, b, c]
#
#
# series s1 has index [0, 1, 2]

# %%
s+s1
# Out:
# a    NaN
# b    NaN
# c    NaN
# 0    NaN
# 1    NaN
# 2    NaN
# dtype: object

# %% [markdown]
# So we have to keep index same for series.

# %%
s1 = pd.Series(list(df["Name"][5:8]), index = ["a", "b", "c"])
s1
# Out:
# a                 Moran, Mr. James
# b          McCarthy, Mr. Timothy J
# c    Palsson, Master Gosta Leonard
# dtype: object

# %%
s
# Out:
# a                           Heikkinen, Miss Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s+s1
# Out:
# a                Heikkinen, Miss LainaMoran, Mr. James
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)Mc...
# c    Allen, Mr. William HenryPalsson, Master Gosta ...
# dtype: object

# %% [markdown]
# ### Dropping any column from Data Frame

# %% [markdown]
# Whatever keys we are dropping, by default it is assuming in the row.
# - We have to drop by giving parameter axis=1

# %% [markdown]
# - By default not modified ni original data frame.
# - In order to modify from original data frame, we pass a parameter inplace= True

# %%
# df.drop('PassengerId') # error

# %%
df.drop("PassengerId", axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                              Heikkinen, Miss Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                        Graham, Miss Margaret Edith
# 888         0       3            Johnston, Miss Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop("PassengerId", axis=1, inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                              Heikkinen, Miss Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                        Graham, Miss Margaret Edith
# 888         0       3            Johnston, Miss Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# Dropping the row, just mention the index of the row to drop, and inplace=True if want to drop from original data frame

# %%
df.drop(1, inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                         Heikkinen, Miss Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                   Graham, Miss Margaret Edith  female
# 888         0       3       Johnston, Miss Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
df.drop(4, inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                         Heikkinen, Miss Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5           0       3                              Moran, Mr. James    male
# 6           0       1                       McCarthy, Mr. Timothy J    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                   Graham, Miss Margaret Edith  female
# 888         0       3       Johnston, Miss Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %% [markdown]
# To see original data frame after dropping

# %%
df.reset_index(drop=True)
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 1           1       3                         Heikkinen, Miss Laina  female
# 2           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3           0       3                              Moran, Mr. James    male
# 4           0       1                       McCarthy, Mr. Timothy J    male
# ..        ...     ...                                           ...     ...
# 884         0       2                         Montvila, Rev. Juozas    male
# 885         1       1                   Graham, Miss Margaret Edith  female
# 886         0       3       Johnston, Miss Catherine Helen "Carrie"  female
# 887         1       1                         Behr, Mr. Karl Howell    male
# 888         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %% [markdown]
# ### Setting a New Index

# %%
df.set_index("Name", inplace=True)

# %%
df
# Out:
#                                               Survived  Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                              0       3    male  22.0
# Heikkinen, Miss Laina                                1       3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female  35.0
# Moran, Mr. James                                     0       3    male   NaN
# McCarthy, Mr. Timothy J                              0       1    male  54.0
# ...                                                ...     ...     ...   ...
# Montvila, Rev. Juozas                                0       2    male  27.0
# Graham, Miss Margaret Edith                          1       1  female  19.0
# Johnston, Miss Catherine Helen "Carrie"              0       3  female   NaN
# Behr, Mr. Karl Howell                                1       1    male  26.0
# Dooley, Mr. Patrick                                  0       3    male  32.0
#
# ...

# %% [markdown]
# Setting the index back to org form

# %%
df.reset_index()
# Out:
#                                              Name  Survived  Pclass     Sex  \
# 0                         Braund, Mr. Owen Harris         0       3    male
# 1                           Heikkinen, Miss Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                                Moran, Mr. James         0       3    male
# 4                         McCarthy, Mr. Timothy J         0       1    male
# ..                                            ...       ...     ...     ...
# 884                         Montvila, Rev. Juozas         0       2    male
# 885                   Graham, Miss Margaret Edith         1       1  female
# 886       Johnston, Miss Catherine Helen "Carrie"         0       3  female
# 887                         Behr, Mr. Karl Howell         1       1    male
# 888                           Dooley, Mr. Patrick         0       3    male
#
# ...

# %% [markdown]
# Getting Details of any particular Key from Data frame

# %%
df.loc['Braund, Mr. Owen Harris']
# Out:
# Survived            0
# Pclass              3
# Sex              male
# Age              22.0
# SibSp               1
# Parch               0
# Ticket      A/5 21171
# Fare             7.25
# Cabin             NaN
# Embarked            S
# Name: Braund, Mr. Owen Harris, dtype: object

# %% [markdown]
# ### Converting Dictionary into DataFrame

# %%
# Key Values are in list
d = {'Key1': [2, 3, 4],
     'Key2': [5, 6, 7],
     'Key3': [8, 9, 1]}
d
# Out:
# {'Key1': [2, 3, 4], 'Key2': [5, 6, 7], 'Key3': [8, 9, 1]}

# %%
pd.DataFrame(d)
# Out:
#    Key1  Key2  Key3
# 0     2     5     8
# 1     3     6     9
# 2     4     7     1

# %%
# Key Values are in tuple
d = {'Key1': (2, 3, 4),
     'Key2': (5, 6, 7),
     'Key3': (8, 9, 1)}
d
# Out:
# {'Key1': (2, 3, 4), 'Key2': (5, 6, 7), 'Key3': (8, 9, 1)}

# %%
pd.DataFrame(d)
# Out:
#    Key1  Key2  Key3
# 0     2     5     8
# 1     3     6     9
# 2     4     7     1

# %%
df1 = pd.read_csv('taxonomy.csv')

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.shape
# Out:
# (290, 4)

# %%
df1.describe()
# Out:
#        taxonomy_id          name  parent_id       parent_name
# count          290           290        279               279
# unique         290           183         60                50
# top            101  Nursing Home  106-06-07  Health Education
# freq             1             4         11                15

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   taxonomy_id  290 non-null    object
#  1   name         290 non-null    object
#  2   parent_id    279 non-null    object
#  3   parent_name  279 non-null    object
# dtypes: object(4)
# memory usage: 9.2+ KB

# %% [markdown]
# ### Null Values in Data Frame

# %%
df1.isnull().sum()
# Out:
# taxonomy_id     0
# name            0
# parent_id      11
# parent_name    11
# dtype: int64

# %% [markdown]
# In ML we have to remove the Null Value
# - Either delete row and col or Imputation

# %% [markdown]
# `Imputation` : Replacing Null Value with Some Value

# %% [markdown]
# - Numerical data will be replaced by mean, median.
# - Categorical Data will be replaced by Mode.

# %% [markdown]
# Removing Null Value from all the rows

# %%
df1.shape  # 290 rows
# Out:
# (290, 4)

# %% [markdown]
# `dataframe.dropna()` by default axis = 0 , so remove null value from rows only.
# - In order to remove null value from col, just give axis =1

# %%
df1.dropna()  # remove null values from rows
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %% [markdown]
# Here we have 279 rows.

# %% [markdown]
# Removing null values from col

# %%
df1.dropna(axis= 1)  # remove null values from cols
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %% [markdown]
# Dropping Null value from any particular column

# %%
df1[["name"]].dropna(axis=1)  # drop from one col
# Out:
#                              name
# 0                       Emergency
# 1               Disaster Response
# 2                  Emergency Cash
# 3               Help Pay for Food
# 4         Help Pay for Healthcare
# ..                            ...
# 285              Workplace Rights
# 286                     Mediation
# 287                        Notary
# 288                Representation
# 289  Translation & Interpretation
#
# [290 rows x 1 columns]

# %% [markdown]
# ### Imputation

# %% [markdown]
# Replacing missing value with some value.
# - Numeric data will be replaced by mean and median >>> Outlier(abnormal) value treatment is done , then use mean. otherwise median
#
# - Categorical data will be replaced by Mode.
# - Input missing value with someconstan

# %%
df1.fillna("SomeValue")
# Out:
#     taxonomy_id                          name  parent_id           parent_name
# 0           101                     Emergency  SomeValue             SomeValue
# 1        101-01             Disaster Response        101             Emergency
# 2        101-02                Emergency Cash        101             Emergency
# 3     101-02-01             Help Pay for Food     101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare     101-02        Emergency Cash
# ..          ...                           ...        ...                   ...
# 285   111-01-07              Workplace Rights     111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation        111                 Legal
# 287      111-03                        Notary        111                 Legal
# 288      111-04                Representation        111                 Legal
# 289      111-05  Translation & Interpretation        111                 Legal
#
# [290 rows x 4 columns]

# %% [markdown]
# Since parent_id is numerical col, we can replace NAN by 0 as

# %%
df1.fillna(0)
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency         0                     0
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
data1 = {
    'A': [1, 2, None, 4, 5, None, 7, 8, 9, 10],
    'B': [None, 11, 12, 13, None, 15, 16, None, 18, 19]
}
df2 = pd.DataFrame(data1)

# %%
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %% [markdown]
# Calculating Mean of Col

# %%
df2['A'].mean()
# Out:
# np.float64(5.75)

# %% [markdown]
# Missing value is imputed by mean oc

# %%
df2['A'].fillna(df2['A'].mean())
# Out:
# 0     1.00
# 1     2.00
# 2     5.75
# 3     4.00
# 4     5.00
# 5     5.75
# 6     7.00
# 7     8.00
# 8     9.00
# 9    10.00
# Name: A, dtype: float64

# %%
df2['A'].median()
# Out:
# np.float64(6.0)

# %%
df2['A'].fillna(df2['A'].median())
# Out:
# 0     1.0
# 1     2.0
# 2     6.0
# 3     4.0
# 4     5.0
# 5     6.0
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# Name: A, dtype: float64

# %%
df2.fillna(0)
# Out:
#       A     B
# 0   1.0   0.0
# 1   2.0  11.0
# 2   0.0  12.0
# 3   4.0  13.0
# 4   5.0   0.0
# 5   0.0  15.0
# 6   7.0  16.0
# 7   8.0   0.0
# 8   9.0  18.0
# 9  10.0  19.0

# %% [markdown]
# ### Other way to impute missing value

# %% [markdown]
# `f-fill` : Forward filling
#
# See the data from the bottom and fill the previous observed value to NaN value

# %%
df2.ffill()
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   2.0  12.0
# 3   4.0  13.0
# 4   5.0  13.0
# 5   5.0  15.0
# 6   7.0  16.0
# 7   8.0  16.0
# 8   9.0  18.0
# 9  10.0  19.0

# %% [markdown]
# `bfill` : Backward Filling
#
# See the data frame from top and fill the next observed value

# %%
df2.bfill()
# Out:
#       A     B
# 0   1.0  11.0
# 1   2.0  11.0
# 2   4.0  12.0
# 3   4.0  13.0
# 4   5.0  15.0
# 5   7.0  15.0
# 6   7.0  16.0
# 7   8.0  18.0
# 8   9.0  18.0
# 9  10.0  19.0

# %% [markdown]
# ### Chechking duplicate rows

# %%
df2.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#                                               Survived  Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                              0       3    male  22.0
# Heikkinen, Miss Laina                                1       3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female  35.0
# Moran, Mr. James                                     0       3    male   NaN
# McCarthy, Mr. Timothy J                              0       1    male  54.0
# ...                                                ...     ...     ...   ...
# Montvila, Rev. Juozas                                0       2    male  27.0
# Graham, Miss Margaret Edith                          1       1  female  19.0
# Johnston, Miss Catherine Helen "Carrie"              0       3  female   NaN
# Behr, Mr. Karl Howell                                1       1    male  26.0
# Dooley, Mr. Patrick                                  0       3    male  32.0
#
# ...

# %% [markdown]
# To describe any one column we have

# %%
df.Age.describe()
# Out:
# count    712.000000
# mean      29.680014
# std       14.542211
# min        0.420000
# 25%       20.000000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df.Fare.describe()
# Out:
# count    889.000000
# mean      32.187420
# std       49.725462
# min        0.000000
# 25%        7.895800
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                              Name  Survived  Pclass     Sex  \
# 0                         Braund, Mr. Owen Harris         0       3    male
# 1                           Heikkinen, Miss Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                                Moran, Mr. James         0       3    male
# 4                         McCarthy, Mr. Timothy J         0       1    male
# ..                                            ...       ...     ...     ...
# 884                         Montvila, Rev. Juozas         0       2    male
# 885                   Graham, Miss Margaret Edith         1       1  female
# 886       Johnston, Miss Catherine Helen "Carrie"         0       3  female
# 887                         Behr, Mr. Karl Howell         1       1    male
# 888                           Dooley, Mr. Patrick         0       3    male
#
# ...

# %% [markdown]
# ### Data Frame based question using Pandas

# %% [markdown]
# 1. What is the average fare paid by the people who survived?

# %%
df.Fare.mean()
# Out:
# np.float64(32.18741957255343)

# %%
df[df["Survived"] == 1]
# Out:
#                                                   Name  Survived  Pclass  \
# 1                                Heikkinen, Miss Laina         1       3
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 6    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 7                  Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 8                       Sandstrom, Miss Marguerite Rut         1       3
# ..                                                 ...       ...     ...
# 873                    Najib, Miss Adele Kiamie "Jane"         1       3
# 877      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)         1       1
# 878       Shelley, Mrs. William (Imanita Parrish Hall)         1       2
# 885                        Graham, Miss Margaret Edith         1       1
# 887                              Behr, Mr. Karl Howell         1       1
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df[df["Survived"] == 1]['Fare'].mean()
# Out:
# np.float64(48.32828768328446)

# %% [markdown]
# 2. What is the average fare paid by the people who survived?

# %%
df[df['Survived'] == 0]['Fare'].mean()
# Out:
# np.float64(22.143558211678833)

# %% [markdown]
# 3. What is the average age of the people who survived?

# %%
df[df['Survived'] == 1]['Age'].mean()
# Out:
# np.float64(28.310276816608997)

# %% [markdown]
# ### Groupby

# %% [markdown]
# Grouping

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. Min, Max, Std of fare/age of people who survived and not survive in one go

# %%
df.groupby('Survived').mean(numeric_only=True)
# Out:
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531022  30.615839  0.554745  0.330292  22.143558
# 1         1.953079  28.310277  0.472141  0.466276  48.328288

# %%
df.groupby('Survived').sum(numeric_only=True)
# Out:
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1387  12950.50    304    181  12134.6699
# 1            666   8181.67    161    159  16479.9461

# %%
df.groupby('Survived').describe()
# Out:
#          Pclass                                                 Age  \
#           count      mean       std  min  25%  50%  75%  max  count
# Survived
# 0         548.0  2.531022  0.736205  1.0  2.0  3.0  3.0  3.0  423.0
# 1         341.0  1.953079  0.863047  1.0  1.0  2.0  3.0  3.0  289.0
#
#                      ... Parch        Fare                             \
#                mean  ...   75%  max  count       mean        std  min
# Survived             ...
# 0         30.615839  ...   0.0  6.0  548.0  22.143558  31.411116  0.0
# 1         28.310277  ...   1.0  5.0  341.0  48.328288  66.683277  0.0
#
#
#               25%   50%   75%       max
# Survived
# 0          7.8542  10.5  26.0  263.0000
# 1         12.4750  26.0  57.0  512.3292
#
# [2 rows x 40 columns]

# %%
df[['Survived', 'Fare']]
# Out:
#      Survived     Fare
# 0           0   7.2500
# 1           1   7.9250
# 2           1  53.1000
# 3           0   8.4583
# 4           0  51.8625
# ..        ...      ...
# 884         0  13.0000
# 885         1  30.0000
# 886         0  23.4500
# 887         1  30.0000
# 888         0   7.7500
#
# [889 rows x 2 columns]

# %%
import numpy as np

# %% [markdown]
# Custpmize group by

# %%
df.groupby(['Survived'])['Fare'].agg(['min', 'max', 'mean', 'median', 'count', 'std', 'var'])
# Out:
#           min       max       mean  median  count        std          var
# Survived
# 0         0.0  263.0000  22.143558    10.5    548  31.411116   986.658180
# 1         0.0  512.3292  48.328288    26.0    341  66.683277  4446.659477

# %% [markdown]
# Groupby based on two column

# %% [markdown]
# How many passengers survived/ not survived for each sex and pclass?

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum()
# Out:
# Sex     Pclass
# female  1         90
#         2         70
#         3         72
# male    1         45
#         2         17
#         3         47
# Name: Survived, dtype: int64

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum().to_frame()
# Out:
#                Survived
# Sex    Pclass
# female 1             90
#        2             70
#        3             72
# male   1             45
#        2             17
#        3             47

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum().to_frame().reset_index()
# Out:
#       Sex  Pclass  Survived
# 0  female       1        90
# 1  female       2        70
# 2  female       3        72
# 3    male       1        45
# 4    male       2        17
# 5    male       3        47

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum().unstack()
# Out:
# Pclass   1   2   3
# Sex
# female  90  70  72
# male    45  17  47

# %%
a = df.groupby('Pclass').sum(numeric_only=True)
a
# Out:
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            135  7073.42     89     77  18106.1292
# 2             87  5168.83     74     70   3801.8417
# 3            119  8889.92    302    193   6706.6451

# %%
a.T
# Out:
# Pclass             1          2          3
# Survived    135.0000    87.0000   119.0000
# Age        7073.4200  5168.8300  8889.9200
# SibSp        89.0000    74.0000   302.0000
# Parch        77.0000    70.0000   193.0000
# Fare      18106.1292  3801.8417  6706.6451

# %%
a.transpose()
# Out:
# Pclass             1          2          3
# Survived    135.0000    87.0000   119.0000
# Age        7073.4200  5168.8300  8889.9200
# SibSp        89.0000    74.0000   302.0000
# Parch        77.0000    70.0000   193.0000
# Fare      18106.1292  3801.8417  6706.6451

# %%
b = a.unstack()
b
# Out:
#           Pclass
# Survived  1           135.0000
#           2            87.0000
#           3           119.0000
# Age       1          7073.4200
#           2          5168.8300
#           3          8889.9200
# SibSp     1            89.0000
#           2            74.0000
#           3           302.0000
# Parch     1            77.0000
#           2            70.0000
#           3           193.0000
# Fare      1         18106.1292
#           2          3801.8417
#           3          6706.6451
# dtype: float64

# %%
b.unstack()
# Out:
# Pclass             1          2          3
# Survived    135.0000    87.0000   119.0000
# Age        7073.4200  5168.8300  8889.9200
# SibSp        89.0000    74.0000   302.0000
# Parch        77.0000    70.0000   193.0000
# Fare      18106.1292  3801.8417  6706.6451

# %% [markdown]
# # Concatenation in Data Frame

# %% [markdown]
# Concatenation means keeping two dataframe either horizontally or vertically

# %%
import pandas as pd

# %%
import numpy as np

# %%
df= pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# If string is not same we cannot concatenate two series.

# %%
df1 = df[["Name", "Sex", "Age"]]
df1
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                                Heikkinen, Miss Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                        Graham, Miss Margaret Edith  female  19.0
# 888            Johnston, Miss Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
# [891 rows x 3 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df1.head()
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                              Heikkinen, Miss Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
df1 = df[["Name", "Sex", "Age"]][0:5]
df1
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                              Heikkinen, Miss Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
df2 = df[["Name", "Sex", "Age"]][5:10]
df2
# Out:
#                                                 Name     Sex   Age
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                      Palsson, Master Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %% [markdown]
# Concatenate pandas DF/ object along a particular axis.
# - By- Default it is taking axis = 0 i.e. row-wise make it verticle concatenation.
# - If we use axis = 1 , we will get horizontal concatenation.

# %%
pd.concat([df1, df2])
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                              Heikkinen, Miss Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                      Palsson, Master Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df1, df2], axis=1)
# where index doesn't match we will have NaN as element
# Out:
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                              Heikkinen, Miss Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                                NaN     NaN   NaN
# 6                                                NaN     NaN   NaN
# 7                                                NaN     NaN   NaN
# 8                                                NaN     NaN   NaN
# 9                                                NaN     NaN   NaN
#
#                                                 Name     Sex   Age
# 0                                                NaN     NaN   NaN
# 1                                                NaN     NaN   NaN
# ...

# %%
df2
# Out:
#                                                 Name     Sex   Age
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                      Palsson, Master Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#                                                 Name     Sex   Age
# 0                                   Moran, Mr. James    male   NaN
# 1                            McCarthy, Mr. Timothy J    male  54.0
# 2                      Palsson, Master Gosta Leonard    male   2.0
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df1, df2], axis=1)
# Out:
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                              Heikkinen, Miss Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#                                                 Name     Sex   Age
# 0                                   Moran, Mr. James    male   NaN
# 1                            McCarthy, Mr. Timothy J    male  54.0
# 2                      Palsson, Master Gosta Leonard    male   2.0
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %% [markdown]
# ## Merging Two data frames.

# %% [markdown]
# `join` Also follow same concepts like merge.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - `inner merge`: Merge based on common column (intersection)
# - `left merge` : Merge based on element of left DataFrame only. All the elements of left DataFrame will be there alongwith common elements.
# - `right merge` : Merge based on element of right DataFrame only. All the elements of right DataFrame will be there alongwith common elements.
# - `outer merge` : Merge based on all the element of both dataframe (Union)
# - `cross join` : Every permutation and combination of rows are there.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df1 = pd.DataFrame({'key1':[1,2,4,5,6],
                    'key2':[4,5,6,7,8],
                    'key3':[3,4,5,6,6]})
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df2 = pd.DataFrame({'key1':[1,2,45,6,67],
                    'key4':[56,5,6,7,8],
                    'key5':[3,56,5,6,6]})
df2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %% [markdown]
# ### Inner merge

# %%
pd.merge(df1, df2, how='inner')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     6     8     6     7     6

# %% [markdown]
# ### Outer merge

# %%
pd.merge(df1, df2, how='outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0  56.0   3.0
# 1     2   5.0   4.0   5.0  56.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   7.0   6.0
# 5    45   NaN   NaN   6.0   5.0
# 6    67   NaN   NaN   8.0   6.0

# %% [markdown]
# ### Left merge

# %%
pd.merge(df1, df2, how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  56.0   3.0
# 1     2     5     4   5.0  56.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6   NaN   NaN
# 4     6     8     6   7.0   6.0

# %% [markdown]
# ### Right merge

# %%
pd.merge(df1, df2, how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0    56     3
# 1     2   5.0   4.0     5    56
# 2    45   NaN   NaN     6     5
# 3     6   8.0   6.0     7     6
# 4    67   NaN   NaN     8     6

# %% [markdown]
# ### Cross merge/ join

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pd.merge(df1, df2, how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1    56     3
# 1        1     4     3       2     5    56
# 2        1     4     3      45     6     5
# 3        1     4     3       6     7     6
# 4        1     4     3      67     8     6
# 5        2     5     4       1    56     3
# 6        2     5     4       2     5    56
# 7        2     5     4      45     6     5
# 8        2     5     4       6     7     6
# 9        2     5     4      67     8     6
# 10       4     6     5       1    56     3
# 11       4     6     5       2     5    56
# 12       4     6     5      45     6     5
# 13       4     6     5       6     7     6
# 14       4     6     5      67     8     6
# 15       5     7     6       1    56     3
# 16       5     7     6       2     5    56
# 17       5     7     6      45     6     5
# 18       5     7     6       6     7     6
# 19       5     7     6      67     8     6
# 20       6     8     6       1    56     3
# ...
